# %%
# !pip install --upgrade ultralytics

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.99 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.6/107.7 GB disk)

# %%
import ultralytics
print(ultralytics.__file__)
# Out:
# /usr/local/lib/python3.10/dist-packages/ultralytics/__init__.py

# %%
from ultralytics import YOLO
model = YOLO('yolov8n-pose.pt')
model.predict(source='/content/5330828-hd_1920_1080_30fps.mp4', save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/378) /content/5330828-hd_1920_1080_30fps.mp4: 384x640 8 persons, 408.0ms
# video 1/1 (frame 2/378) /content/5330828-hd_1920_1080_30fps.mp4: 384x640 8 persons, 179.7ms
# video 1/1 (frame 3/378) /content/5330828-hd_1920_1080_30fps.mp4: 384x640 8 persons, 172.7ms
# video 1/1 (frame 4/378) /content/5330828-hd_1920_1080_30fps.mp4: 384x640 8 persons, 162.5ms
# ...

# %%
# prompt: how to find coco128.yaml

import ultralytics
from ultralytics import YOLO
# Assuming you have ultralytics installed and YOLO model loaded

# Get the path to the default YOLOv8 repository (where coco128.yaml is located)
yolov8_repo_path = ultralytics.__file__.replace('__init__.py', '')

# Construct the path to coco128.yaml
coco128_yaml_path = yolov8_repo_path + 'ultralytics/data/coco128.yaml'

# Print the path to verify it exists
print(coco128_yaml_path)

# Optional: You can also open the file and read its content to see the data
try:
    with open(coco128_yaml_path, 'r') as f:
        print(f.read())
except FileNotFoundError:
    print(f"File not found: {coco128_yaml_path}")
